# %%
# ==========================================
# Bootstrap Project
# ==========================================

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# /Users/shripat/Walsh/Term3/BhavCo

# %%
from sqlalchemy import text

from config.settings import *
from config.database import engine

# %%
#verify config
print("="*60)
print("PROJECT CONFIGURATION")
print("="*60)

print(f"Project Root      : {PROJECT_ROOT}")
print(f"Database          : {DB_NAME}")
print(f"Bhavcopy Path     : {BHAVCOPY_PATH}")
print(f"India VIX Path    : {VIX_PATH}")
print(f"T-Bill Path       : {TBILL_PATH}")
# Out:
# ============================================================
# PROJECT CONFIGURATION
# ============================================================
# Project Root      : /Users/shripat/Walsh/Term3/BhavCo
# Database          : option_writing
# Bhavcopy Path     : /Users/shripat/Walsh/Term3/BhavCo/data/raw/bhavcopy
# India VIX Path    : /Users/shripat/Walsh/Term3/BhavCo/data/raw/india_vix
# T-Bill Path       : /Users/shripat/Walsh/Term3/BhavCo/data/raw/risk_free_rate

# %%
#Verify Database Connection
print("="*60)
print("DATABASE CONNECTION")
print("="*60)

with engine.connect() as conn:

    version = conn.execute(text("SELECT VERSION();")).scalar()

print(f"Connection Status : SUCCESS")
print(f"MariaDB Version   : {version}")
# Out:
# ============================================================
# DATABASE CONNECTION
# ============================================================
# Connection Status : SUCCESS
# MariaDB Version   : 12.1.2-MariaDB
